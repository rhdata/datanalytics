# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#C:\Users\Philippe\AppData\Local\Programs\Python\Python38-32\Scripts

animals = pd.read_csv('fr_animaux.csv')
veggie = pd.read_csv('fr_vegetaux.csv') 
animals["origine"] = "animal"
veggie["origine"] = "vegetal"

animals.head()
veggie.head()

animals.columns
veggie.columns
# Out:
# Index(['Code Domaine', 'Domaine', 'Code zone', 'Zone', 'Code Élément',
#        'Élément', 'Code Produit', 'Produit', 'Code année', 'Année', 'Unité',
#        'Valeur', 'Symbole', 'Description du Symbole', 'origine'],
#       dtype='object')

# %%
aniveg = animals.append(veggie)
aniveg
# Out:
#        Code Domaine                                            Domaine  \
# 0              FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 1              FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 2              FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 3              FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 4              FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# ...             ...                                                ...
# 104866         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 104867         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 104868         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 104869         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
# 104870         FBSH  Bilans Alimentaire (Ancienne méthodologie et p...
#
#         Code zone         Zone  Code Élément  \
# 0               2  Afghanistan          5511
# ...

# %%
aniveg.columns
# Out:
# Index(['Code Domaine', 'Domaine', 'Code zone', 'Zone', 'Code Élément',
#        'Élément', 'Code Produit', 'Produit', 'Code année', 'Année', 'Unité',
#        'Valeur', 'Symbole', 'Description du Symbole', 'origine'],
#       dtype='object')

# %%
aniveg['Élément'].value_counts()
# Out:
# Disponibilité intérieure                                         15478
# Importations - Quantité                                          14946
# Disponibilité alimentaire (Kcal/personne/jour)                   14333
# Disponibilité alimentaire en quantité (kg/personne/an)           14107
# Nourriture                                                       14107
# Exportations - Quantité                                          12320
# Disponibilité de matière grasse en quantité (g/personne/jour)    11877
# Disponibilité de protéines en quantité (g/personne/jour)         11641
# Production                                                        9271
# Variation de stock                                                6857
# Autres utilisations (non alimentaire)                             5571
# Pertes                                                            4329
# Aliments pour animaux                                             2757
# ...

# %%
aniveg[['Élément', 'Unité']].drop_duplicates()
# Out:
#                                                Élément               Unité
# 0                                           Production  Milliers de tonnes
# 1                              Importations - Quantité  Milliers de tonnes
# 2                             Disponibilité intérieure  Milliers de tonnes
# 3                                           Nourriture  Milliers de tonnes
# 4    Disponibilité alimentaire en quantité (kg/pers...                  kg
# 5       Disponibilité alimentaire (Kcal/personne/jour)  Kcal/personne/jour
# 6    Disponibilité de protéines en quantité (g/pers...     g/personne/jour
# 7    Disponibilité de matière grasse en quantité (g...     g/personne/jour
# 64                                            Semences  Milliers de tonnes
# 65                                              Pertes  Milliers de tonnes
# 73                             Exportations - Quantité  Milliers de tonnes
# ...

# %%
datapop = pd.read_csv("fr_population.csv") 
datapop.drop(['Code Domaine', 'Domaine', 'Code Élément',
       'Élément', 'Code Produit', 'Produit', 'Code année', 'Année', 'Unité'
      , 'Symbole', 'Description du Symbole'],axis=1, inplace=True)
datapop['Valpop'] = datapop ['Valeur']*1000

# %%
data2 = aniveg.pivot_table(
    index=["Code zone","Zone","Produit","Année","origine"],
    columns = ["Élément"], values =["Valeur"], aggfunc=sum)
data2.columns = ['Aliments pour animaux',  'Autres Utilisations', 'Disponibilité alimentaire (Kcal/personne/jour)','Disponibilité alimentaire en quantité (kg/personne/an)', 'Disponibilité de matière grasse en quantité (g/personne/jour)', 'Disponibilité de protéines en quantité (g/personne/jour)', 'Disponibilité intérieure',  'Exportations','Importations',  'Nourriture', 'Pertes','Production',  'Semences','Transformés',  'Variation de stock' 
]   
data3 = data2.reset_index()
data3.head()
# Out:
#    Code zone     Zone                 Produit  Année  origine  \
# 0          1  Arménie        Abats Comestible   2013   animal
# 1          1  Arménie         Agrumes, Autres   2013  vegetal
# 2          1  Arménie  Alcool, non Comestible   2013  vegetal
# 3          1  Arménie   Aliments pour enfants   2013  vegetal
# 4          1  Arménie                  Ananas   2013  vegetal
#
#    Aliments pour animaux  Autres Utilisations  \
# 0                    NaN                  3.0
# 1                    NaN                  NaN
# 2                    NaN                  0.0
# 3                    NaN                  NaN
# 4                    NaN                  NaN
#
#    Disponibilité alimentaire (Kcal/personne/jour)  \
# 0                                            14.0
# 1                                             0.0
# 2                                             NaN
# 3                                             2.0
# 4                                             0.0
#
# ...

# %%
armenia= data3.loc[ data3['Zone'] == 'Arménie']
armenia = armenia.loc[armenia['Produit']== 'Blé']
armenia
# Out:
#     Code zone     Zone Produit  Année  origine  Aliments pour animaux  \
# 12          1  Arménie     Blé   2013  vegetal                   93.0
#
#     Autres Utilisations  Disponibilité alimentaire (Kcal/personne/jour)  \
# 12                  0.0                                          1024.0
#
#     Disponibilité alimentaire en quantité (kg/personne/an)  \
# 12                                              130.6
#
#     Disponibilité de matière grasse en quantité (g/personne/jour)  \
# 12                                                3.6
#
#     Disponibilité de protéines en quantité (g/personne/jour)  \
# 12                                              30.52
#
#     Disponibilité intérieure  Exportations  Importations  Nourriture  Pertes  \
# 12                     554.0           1.0         361.0       389.0    32.0
#
#     Production  Semences  Transformés  Variation de stock
# 12       312.0      30.0         10.0              -118.0

# %%
df44 = data3.merge(datapop)
df44
# Out:
#        Code zone     Zone                 Produit  Année  origine  \
# 0              1  Arménie        Abats Comestible   2013   animal
# 1              1  Arménie         Agrumes, Autres   2013  vegetal
# 2              1  Arménie  Alcool, non Comestible   2013  vegetal
# 3              1  Arménie   Aliments pour enfants   2013  vegetal
# 4              1  Arménie                  Ananas   2013  vegetal
# ...          ...      ...                     ...    ...      ...
# 15600        276   Soudan        Viande de Suides   2013   animal
# 15601        276   Soudan     Viande de Volailles   2013   animal
# 15602        276   Soudan           Viande, Autre   2013   animal
# 15603        276   Soudan                     Vin   2013  vegetal
# 15604        276   Soudan          Épices, Autres   2013  vegetal
#
#        Aliments pour animaux  Autres Utilisations  \
# 0                        NaN                  3.0
# 1                        NaN                  NaN
# ...

# %%
Question1

# %%
datapop
# Out:
#      Code zone                                    Zone  Valeur    Valpop
# 0            2                             Afghanistan   30552  30552000
# 1          202                          Afrique du Sud   52776  52776000
# 2            3                                 Albanie    3173   3173000
# 3            4                                 Algérie   39208  39208000
# 4           79                               Allemagne   82727  82727000
# ..         ...                                     ...     ...       ...
# 170        236  Venezuela (République bolivarienne du)   30405  30405000
# 171        237                                Viet Nam   91680  91680000
# 172        249                                   Yémen   24407  24407000
# 173        251                                  Zambie   14539  14539000
# 174        181                                Zimbabwe   14150  14150000
#
# [175 rows x 4 columns]

# %%
datapop[datapop['Zone'].str.contains('Chine')][['Code zone', 'Zone', 'Valeur']]
# Out:
#     Code zone                       Zone   Valeur
# 33        351                      Chine  1416667
# 34         96   Chine - RAS de Hong-Kong     7204
# 35        128       Chine - RAS de Macao      566
# 36         41        Chine, continentale  1385567
# 37        214  Chine, Taiwan Province de    23330

# %%
datapop['Valpop'].sum()
# Out:
# 8413993000

# %%
datapop = datapop[datapop['Code zone'] != 351]

# %%
POP_MONDIALE = datapop['Valpop'].sum()

# %%
POP_MONDIALE/1e9
# Out:
# 6.997326

# %%
La population mondiale est de 6.997326 milliards d'humains

# %%
Question2

# %%
Disponibilité intérieure = Nourriture + Pertes + Semences + Autres~utilisations + Aliments~pour~animaux + traitement
Disponibilité intérieure = Production + Importation - Exportation + evolution~stock

# %%
Question3

# %%
DISPO ALIMENTAIRE EN Kcal/an

# %%
df44['disp_alim__kcal_an']= df44['Disponibilité alimentaire (Kcal/personne/jour)'] * df44['Valpop'] * 365

# %%
DISPO ALIMENTAIRE EN Kg de prot/an

# %%
df44['disp_prot__kg_an']= df44['Disponibilité de protéines en quantité (g/personne/jour)'] / 1000 *df44['Valpop'] *365

# %%
Verification

# %%
armenia= df44.loc[ df44['Zone'] == 'Barbade']
armenia = armenia.loc[armenia['Produit']== 'Raisin']
armenia
# Out:
#      Code zone     Zone Produit  Année  origine  Aliments pour animaux  \
# 954         14  Barbade  Raisin   2013  vegetal                    NaN
#
#      Autres Utilisations  Disponibilité alimentaire (Kcal/personne/jour)  \
# 954                  0.0                                            14.0
#
#      Disponibilité alimentaire en quantité (kg/personne/an)  \
# 954                                               7.81
#
#      Disponibilité de matière grasse en quantité (g/personne/jour)  ...  \
# 954                                               0.09              ...
#
#      Production  Semences  Transformés  Variation de stock  Valeur  Valpop  \
# 954         NaN       NaN          NaN                 NaN     285  285000
#
#      disp_alim__kcal_an  disp_alim__kg_an  ratio_e_pds__kcal_kg  \
# 954        1.456350e+09         2225850.0               728.175
#
#      disp_prot__kg_an
# 954           12483.0
#
# [1 rows x 26 columns]

# %%
Question4

# %%
df44['disp_alim__kg_an']= df44['Disponibilité alimentaire en quantité (kg/personne/an)'] *df44['Valpop']

# %%
df44['ratio_e_pds__kcal_kg'] = df44['disp_alim__kcal_an'] / (df44['Nourriture'] * 1000*1000)
df44
# Out:
#        Code zone     Zone                 Produit  Année  origine  \
# 0              1  Arménie        Abats Comestible   2013   animal
# 1              1  Arménie         Agrumes, Autres   2013  vegetal
# 2              1  Arménie  Alcool, non Comestible   2013  vegetal
# 3              1  Arménie   Aliments pour enfants   2013  vegetal
# 4              1  Arménie                  Ananas   2013  vegetal
# ...          ...      ...                     ...    ...      ...
# 15600        276   Soudan        Viande de Suides   2013   animal
# 15601        276   Soudan     Viande de Volailles   2013   animal
# 15602        276   Soudan           Viande, Autre   2013   animal
# 15603        276   Soudan                     Vin   2013  vegetal
# 15604        276   Soudan          Épices, Autres   2013  vegetal
#
#        Aliments pour animaux  Autres Utilisations  \
# 0                        NaN                  3.0
# 1                        NaN                  NaN
# ...

# %%
armenia= df44.loc[ df44['Zone'] == 'Tchéquie (la)']
armenia = armenia.loc[armenia['Produit']== 'Boissons Alcooliques']
armenia
# Out:
#        Code zone           Zone               Produit  Année  origine  \
# 10629        167  Tchéquie (la)  Boissons Alcooliques   2013  vegetal
#
#        Aliments pour animaux  Autres Utilisations  \
# 10629                    NaN                  NaN
#
#        Disponibilité alimentaire (Kcal/personne/jour)  \
# 10629                                            47.0
#
#        Disponibilité alimentaire en quantité (kg/personne/an)  \
# 10629                                               5.76
#
#        Disponibilité de matière grasse en quantité (g/personne/jour)  ...  \
# 10629                                                NaN              ...
#
#        Production  Semences  Transformés  Variation de stock  Valeur  \
# 10629        63.0       NaN          NaN                 NaN   10702
#
#          Valpop  disp_alim__kcal_an  disp_alim__kg_an  ratio_e_pds__kcal_kg  \
# 10629  10702000        1.835928e+11        61643520.0           2961.174355
#
#        disp_prot__kg_an
# ...

# %%
oeufs = df44.loc[ df44['Produit'] == 'Oeufs']
oeufs
# Out:
#        Code zone         Zone Produit  Année origine  Aliments pour animaux  \
# 55             1      Arménie   Oeufs   2013  animal                    NaN
# 127            2  Afghanistan   Oeufs   2013  animal                    NaN
# 205            3      Albanie   Oeufs   2013  animal                    NaN
# 297            4      Algérie   Oeufs   2013  animal                    NaN
# 382            7       Angola   Oeufs   2013  animal                    NaN
# ...          ...          ...     ...    ...     ...                    ...
# 15209        255     Belgique   Oeufs   2013  animal                    NaN
# 15303        256   Luxembourg   Oeufs   2013  animal                    NaN
# 15395        272       Serbie   Oeufs   2013  animal                    NaN
# 15486        273   Monténégro   Oeufs   2013  animal                    NaN
# 15570        276       Soudan   Oeufs   2013  animal                    NaN
#
# ...

# %%
df44['disp_alim__kcal_an']= df44['Disponibilité alimentaire (Kcal/personne/jour)'] * df44['Valpop'] * 365

# %%
df44['prc_prot'] = df44['disp_prot__kg_an'] / df44['disp_alim__kg_an'] * 100

# %%
df44['prc_prot'] = df44['disp_prot__kg_an'] / df44['disp_alim__kg_an'] * 100

# %%
ratio_ep_oeuf = df44.loc[
    (df44['Produit']=='Oeufs')
    & (df44['ratio_e_pds__kcal_kg']!=np.inf)
    & (df44['ratio_e_pds__kcal_kg']!=0),
    ['ratio_e_pds__kcal_kg']
].mean().values[0]

# %%
ratio_ep_oeuf/10
# Out:
# 134.53003859252402

# %%
le ratio energie poids d'un oeuf est de 134.53003859252402 kcal pour 100gr

# %%
verif = df44.loc[
    (df44['Produit'] == 'Avoine'), 
    'prc_prot'
].mean()
verif
# Out:
# 7.969708659648603

# %%
avoine =df44.loc[ df44['Produit'] == 'Avoine']
avoine = avoine[['Zone', 'Produit','ratio_e_pds__kcal_kg']]
avoine
# Out:
#                      Zone Produit  ratio_e_pds__kcal_kg
# 7                 Arménie  Avoine              2173.210
# 157               Albanie  Avoine                   inf
# 249               Algérie  Avoine                   NaN
# 341                Angola  Avoine                   NaN
# 421    Antigua-et-Barbuda  Avoine                   inf
# ...                   ...     ...                   ...
# 15159            Belgique  Avoine              2026.480
# 15254          Luxembourg  Avoine              1741.050
# 15347              Serbie  Avoine              3471.515
# 15439          Monténégro  Avoine                   NaN
# 15527              Soudan  Avoine                   NaN
#
# [167 rows x 3 columns]

# %%
Question5

# %%
Les 5 aliments les plus caloriques

# %%
alim_ratio_e_pds_desc = df44.loc[(df44['ratio_e_pds__kcal_kg'] != 0)
    & (df44['ratio_e_pds__kcal_kg'] != np.inf),
    ['Produit', 'ratio_e_pds__kcal_kg']
]


alim_ratio_e_pds_desc = alim_ratio_e_pds_desc.groupby('Produit').mean().reset_index().sort_values(by='ratio_e_pds__kcal_kg', ascending=False)

# %%
alim_ratio_e_pds_desc.head(5)
# Out:
#                      Produit  ratio_e_pds__kcal_kg
# 45  Huiles de Foie de Poisso           9982.932500
# 43           Huile de Sésame           9433.744729
# 42       Huile de Son de Riz           9361.549883
# 46        Huiles de Poissons           9003.715504
# 34          Huile d'Arachide           8935.765811

# %%
alim_prct_prot_desc = df44.loc[(df44['prc_prot'] != 0)
    & (df44['prc_prot'] != np.inf),
    ['Produit', 'prc_prot']
]

# groupy, sort...
alim_prct_prot_desc = alim_prct_prot_desc.groupby('Produit').mean().reset_index().sort_values(by='prc_prot', ascending=False)

# %%
Aliments les protéines

# %%
alim_prct_prot_desc.head(5)
# Out:
#                    Produit   prc_prot
# 27  Graines Colza/Moutarde  36.500000
# 81                    Soja  27.254546
# 6   Arachides Decortiquees  25.091310
# 70                    Pois  22.423943
# 50     Légumineuses Autres  22.304684

# %%
Question6

# %%
vegetaux = df44.loc[
    df44['origine'] == 'vegetal',
    ['Zone', 'Produit', 'Disponibilité intérieure']
]

# %%
df66 = pd.merge(
    vegetaux,
    alim_ratio_e_pds_desc,
    how='left'
)

# %%
df66['disp_inter__kcal'] = df66['Disponibilité intérieure'] * 1e6 * df66['ratio_e_pds__kcal_kg']

# %%
armenia= df66.loc[ df66['Zone'] =='Arménie']
armenia = armenia.loc[armenia['Produit']== 'Avoine']
armenia
# Out:
#       Zone Produit  Disponibilité intérieure  ratio_e_pds__kcal_kg  \
# 5  Arménie  Avoine                       6.0           2143.296415
#
#    disp_inter__kcal
# 5      1.285978e+10

# %%
disp_interieure_mond_vegetaux__kcal = df66.disp_inter__kcal.sum()
disp_interieure_mond_vegetaux__kcal
disp_interieure_mond_vegetaux__kcal / 1e6 / 1e9
# Out:
# 13.764013420014768

# %%
La disponibilité interieure mondiale des produits vegetaux est de 13.77 millions de milliards de kcal

# %%
Question7

# %%
Nombre de personnes nourrissable en calories

# %%
BESOIN_QUOTIDIEN = {
    'kcal': 2400, 
    'g_prot': 55
}
nb_per_nrsable_cal  =  disp_inter_monde_vegetaux__kcal / (BESOIN_QUOTIDIEN['kcal'] * 365)
nb_per_nrsable_cal/ 1e9
# Out:
# 15.712344086774849

# %%
On peut subvenir aux besoins caloriques de 15.71 milliards d'etres humains

# %%
df8 = pd.merge(
    vegetaux[['Zone', 'Produit', 'Disponibilité intérieure']],
    alim_prct_prot_desc,
    how='left'
)
df8
# Out:
#           Zone                 Produit  Disponibilité intérieure   prc_prot
# 0      Arménie         Agrumes, Autres                       1.0   0.447068
# 1      Arménie  Alcool, non Comestible                       0.0        NaN
# 2      Arménie   Aliments pour enfants                       0.0  15.431743
# 3      Arménie                  Ananas                       0.0   0.305591
# 4      Arménie  Arachides Decortiquees                       1.0  25.091310
# ...        ...                     ...                       ...        ...
# 11891   Soudan                  Sésame                     142.0  18.710715
# 11892   Soudan                     Thé                      25.0   9.490231
# 11893   Soudan                 Tomates                     592.0   0.947236
# 11894   Soudan                     Vin                       0.0   0.007100
# 11895   Soudan          Épices, Autres                       2.0  11.084927
#
# [11896 rows x 4 columns]

# %%
Nombre de personnes nourrissables en protéines

# %%
df8['disp_inter_prot__kg'] = df8['Disponibilité intérieure'] * 1e6 * (df8['prc_prot'] / 100)
disp_inter_prot_monde_vegetaux__kg = df8.disp_inter_prot__kg.sum()
nb_per_nrsable_prot = (disp_inter_prot_monde_vegetaux__kg * 1000) / (BESOIN_QUOTIDIEN['g_prot'] * 365)
nb_per_nrsable_prot/1e9
# Out:
# 17.558835551693893

# %%
On peut subvenir aux besoins en proteines de 17.56 milliards d'etres humains

# %%
Question8

# %%
df8 = df44.loc[
    df44['origine'] == 'vegetal',
    ['Zone', 'Produit', 'disp_alim__kg_an', 'Aliments pour animaux', 'Pertes']
]

df8['total_kg'] = df_1['disp_alim__kg_an'] + df_1['Aliments pour animaux'] * 1e6 + df_1['Pertes'] * 1e6

# %%
df8 = pd.merge(
    df8,
    alim_prct_prot_desc,
    how='left'
)

df8 = pd.merge(
    df8,
    alim_ratio_e_pds_desc,
    how='left'
)

df8 = df8[['Zone', 'Produit', 'total_kg', 'ratio_e_pds__kcal_kg', 'prc_prot']]

# %%
# total en kcal
df8['total_kcal'] = df8['total_kg'] * df8['ratio_e_pds__kcal_kg']
# total en protéines
df8['total_prot_kg'] = df8['total_kg'] * (df8['prc_prot'] / 100)

# %%
total_kcal = df8.total_kcal.sum()
total_prot_kg = df8.total_prot_kg.sum()

# %%
besoin_cal =  total_kcal / (BESOIN_QUOTIDIEN['kcal'] * 365)
besoin_prot = (total_prot_kg * 1e3) / (BESOIN_QUOTIDIEN['g_prot'] * 365)

# %%
besoin_cal/1e9
# Out:
# 7.132097388300865

# %%
besoin_prot/1e9
# Out:
# 8.220620036782254

# %%
On pourrait satisfaire en besoins de calories :7.1320 et en besoin de protéines : 8.2206 milliards d'etres humains soient respectivement 
        98% de la population et 117% de la population

# %%
Question9

# %%
df99 = df44[['Zone', 'Produit', 'disp_alim__kcal_an', 'disp_alim__kg_an']]

# %%
df99 = pd.merge(
    df44,
    alim_prct_prot_desc,
    how='left'
)

# %%
df99['disp_alim_prot__kg'] = df99['disp_alim__kg_an'] * (df99['prc_prot'] / 100)

## pays | produit | disp_alim__kcal_an | disp_alim_prot__kg
df99 = df99[['Zone', 'Produit', 'disp_alim__kcal_an','disp_alim_prot__kg']]

# %%
disp_alim__kcal = df99.disp_alim__kcal_an.sum()
disp_alim_prot__kg = df99.disp_alim_prot__kg.sum()

# %%
nb_per_kcal = disp_alim__kcal / (BESOIN_QUOTIDIEN['kcal'] * 365)
nb_per_prot = (disp_alim_prot__kg * 1000) / (BESOIN_QUOTIDIEN['g_prot'] * 365)
nb_per_kcal/ 1e9
# Out:
# 10.24320448875

# %%
nb_per_prot/ 1e9
# Out:
# 12.84487234909091

# %%
La disponibilité alimentaire mondiale pourrait nourrir en calories :10.24  et en besoin de protéines : 12.85 milliards d'etres humains soient respectivement 
        146% de la population et 183% de la population

# %%
Question10

# %%
df10 = pd.read_csv('fr_sousalimentation.csv')

# %%
df101 = df10.loc[~pd.isnull(sous_alim_df.Valeur) , ['Zone', 'Valeur'] ]
# df.rename(index=str, columns={"A": "a", "C": "c"})
df101 = df101.rename(columns={'Valeur': 'popss_alim'})
df101
# Out:
#              Zone popss_alim
# 0     Afghanistan        7.9
# 1     Afghanistan        8.8
# 2     Afghanistan        9.6
# 3     Afghanistan       10.2
# 4     Afghanistan       10.6
# ...           ...        ...
# 1015     Zimbabwe        6.6
# 1016     Zimbabwe        7.2
# 1017     Zimbabwe        7.8
# 1018     Zimbabwe        8.2
# 1019     Zimbabwe        8.5
#
# [605 rows x 2 columns]

# %%
df101.dtypes
# Out:
# Zone          object
# popss_alim    object
# dtype: object

# %%
nb_per_ss_alim = df101[['popss_alim']].drop_duplicates()

# %%
res= nb_per_ss_alim.popss_alim.sum()

# %%
sous_nutrition = 794900000/6997326000*100
sous_nutrition
# Out:
# 11.360053826275923

# %%
Il y a 11% de la population qui est en sous-nutrition

# %%
Question11

# %%
dfcere = pd.read_csv('fr_cereales.csv')
dfcere['origine'] = 'cereale'
dfcere = dfcere[dfcere['Code zone'] != 351]

# %%
df44['is_cereal'] = ((df44['Produit'] == 'Blé') | (df44['Produit'] == 'Orge') | (df44['Produit'] == 'Maïs') | (df44['Produit'] == 'Seigle') | (df44['Produit'] == 'Avoine') | (df44['Produit'] == 'Millet')| (df44['Produit'] == 'Sorgho')| (df44['Produit'] == 'Céréales, Autres') | (df44['Produit'] == 'Riz (Eq Blanchi)'))

# %%
cereal = df44[['Produit', 'is_cereal']]
cereal =cereal.loc[ df44['is_cereal'] == True]
cereal
# Out:
#                 Produit  is_cereal
# 7                Avoine       True
# 12                  Blé       True
# 21     Céréales, Autres       True
# 49                 Maïs       True
# 51               Millet       True
# ...                 ...        ...
# 15659            Millet       True
# 15667              Orge       True
# 15684  Riz (Eq Blanchi)       True
# 15685            Seigle       True
# 15687            Sorgho       True
#
# [1506 rows x 2 columns]

# %%
cereal =df44.loc[df44['is_cereal'] == True]
total_cereal = cereal['Nourriture'].sum()+cereal['Aliments pour animaux'].sum()
total_cereal
# Out:
# 2312022.0

# %%
percetange_alim_ani = cereal['Aliments pour animaux'].sum()/ total_cereal
percentage = percetange_alim_ani*100
percentage
# Out:
# 46.30652303481541

# %%
Human_food = 100 - percentage
Human_food
# Out:
# 53.69347696518459

# %%
L'alimentation destinée a l'alimentation animale represente 46.30%

# %%
df_2 = data3[['Produit', 'Exportations']]\
.groupby(by=['Produit']).sum().reset_index()\
.sort_values(by='Exportations', ascending=False)

produit_export_par_pays_ss_alim = df_2.Produit[:15]

# %%
Les 15 produits exportés

# %%
produit_export_par_pays_ss_alim
# Out:
# 12                    Blé
# 52                   Maïs
# 48     Lait - Excl Beurre
# 81                   Soja
# 83          Sucre Eq Brut
# 49        Légumes, Autres
# 39         Huile de Palme
# 62                   Orge
# 79       Riz (Eq Blanchi)
# 61    Oranges, Mandarines
# 51                 Manioc
# 25         Fruits, Autres
# 76        Pommes de Terre
# 89                Tomates
# 73    Poissons Pelagiques
# Name: Produit, dtype: object

# %%
df15 = df44.loc[
    df44['Produit'].isin(produit_export_par_pays_ss_alim)].sort_values('Importations', ascending=False)[:200]

# %%
df151 = df15[['Zone', 'Produit','Autres Utilisations','Disponibilité intérieure','Aliments pour animaux','Nourriture']]

# %%
df152 = df151.groupby('Produit').sum().reset_index()

# %%
df153 = df152.copy()
df153['ratio__autre_util__disp_inter'] = df153['Autres Utilisations'] / df153['Disponibilité intérieure']
df153['ratio__alim_pr_anim__nourriture_anim_hum'] = df153['Aliments pour animaux'] / (df153['Aliments pour animaux'] + df153['Nourriture'])

df153 = df153[['Produit', 'ratio__autre_util__disp_inter', 'ratio__alim_pr_anim__nourriture_anim_hum']]

# %%
df153
# Out:
#                 Produit  ratio__autre_util__disp_inter  \
# 0                   Blé                       0.032140
# 1        Fruits, Autres                       0.000000
# 2        Huile de Palme                       0.724803
# 3    Lait - Excl Beurre                       0.036166
# 4       Légumes, Autres                       0.000000
# 5                Manioc                       0.302335
# 6                  Maïs                       0.264426
# 7   Oranges, Mandarines                       0.000051
# 8                  Orge                       0.000407
# 9   Poissons Pelagiques                       0.000000
# 10      Pommes de Terre                       0.065253
# 11     Riz (Eq Blanchi)                       0.017190
# 12                 Soja                       0.003284
# 13        Sucre Eq Brut                       0.038188
# 14              Tomates                       0.000000
#
#     ratio__alim_pr_anim__nourriture_anim_hum
# ...

# %%
Question12

# %%
df44.columns
# Out:
# Index(['Code zone', 'Zone', 'Produit', 'Année', 'origine',
#        'Aliments pour animaux', 'Autres Utilisations',
#        'Disponibilité alimentaire (Kcal/personne/jour)',
#        'Disponibilité alimentaire en quantité (kg/personne/an)',
#        'Disponibilité de matière grasse en quantité (g/personne/jour)',
#        'Disponibilité de protéines en quantité (g/personne/jour)',
#        'Disponibilité intérieure', 'Exportations', 'Importations',
#        'Nourriture', 'Pertes', 'Production', 'Semences', 'Transformés',
#        'Variation de stock', 'Valeur', 'Valpop', 'disp_alim__kcal_an',
#        'disp_prot__kg_an', 'disp_alim__kg_an', 'ratio_e_pds__kcal_kg',
#        'prc_prot', 'is_cereal'],
#       dtype='object')

# %%
df44['ratio__autre_util__disp_inter'] = df44['Autres Utilisations'] / df44['Disponibilité intérieure']
df44['ratio__alim_pr_anim__nourriture_anim_hum'] = df44['Aliments pour animaux'] / (df44['Aliments pour animaux'] + df44['Nourriture'])

# %%
ratio__autre_util__disp_inter__3max = df44[['Produit', 'ratio__autre_util__disp_inter']]\
.sort_values('ratio__autre_util__disp_inter', ascending=False)[:3]#.produit.values

# %%
les 3 produits qui ont la plus grande valeur

# %%
ratio__autre_util__disp_inter__3max
# Out:
#                        Produit  ratio__autre_util__disp_inter
# 14295  Huil Plantes Oleif Autr                       5.045455
# 14476   Graisses Animales Crue                       3.500000
# 10372           Huile de Palme                       2.000000

# %%
Question13

# %%
qt_cere_anim_ktonne = df44.loc[
    (df44.Zone == "États-Unis d'Amérique")
    & (df44.Produit.isin(code_cerales)),
    'Aliments pour animaux'
].sum()

# %%
reponse = qt_cere_anim_ktonne * 0.1

# %%
reponse 14 milles tonnes de cereals
# Out:
# 14009.6

# %%
cereus = df44.loc[
    (df44.Zone == "États-Unis d'Amérique")
    & (df44.Produit.isin(code_cerales)),
    ['Aliments pour animaux', 'ratio_e_pds__kcal_kg', 'prc_prot']
]

# %%
cereus['alim_pr_anim__kcal'] = cereus['Aliments pour animaux'] * 1e6 * cereus['ratio_e_pds__kcal_kg']

# %%
qt_cere_anim_kcal = cereus['alim_pr_anim__kcal'].sum()

# %%
# 10% des céréales utilisé pour nourrir les animaux pourrait nourrir combien d'humains ?
nb_per_nrsable = (qt_cere_anim_kcal*0.1) / (BESOIN_QUOTIDIEN['kcal'] * 365)

# %%
nb_per_nrsable
# Out:
# 43920189.54537864

# %%
On pourrait nourrir 43 millions de personnes

# %%
Question14

# %%
thai = df44.loc[
    (df44['Zone'] == 'Thaïlande')
    &(df44['Produit'] == 'Manioc'),
].iloc[0]

# %%
thai
# Out:
# Code zone                                                                216
# Zone                                                               Thaïlande
# Produit                                                               Manioc
# Année                                                                   2013
# origine                                                              vegetal
# Aliments pour animaux                                                   1800
# Autres Utilisations                                                     2081
# Disponibilité alimentaire (Kcal/personne/jour)                            40
# Disponibilité alimentaire en quantité (kg/personne/an)                    13
# Disponibilité de matière grasse en quantité (g/personne/jour)           0.05
# Disponibilité de protéines en quantité (g/personne/jour)                0.14
# Disponibilité intérieure                                                6264
# ...

# %%
proportion_manioc_export = thai['Exportations'] / thai['Production']

# %%
proportion_manioc_export * 100
# Out:
# 83.41272991928014

# %%
Pour la Thailande, 83% de la production est exportée

# %%
sousalim_df = pd.read_csv('fr_sousalimentation2.csv')

# %%
soussalim__df = sousalim_df.loc[~pd.isnull(sousalim_df.Valeur) , ['Code zone', 'Valeur'] ]
# df.rename(index=str, columns={"A": "a", "C": "c"})
sous_alim__df = sous_alim__df.rename(columns={'Valeur': 'pop_ss_alim'})

# %%
thai2 = df44.merge(sous_alim__df)

# %%
armenia= thai2.loc[thai2['Zone'] == 'Thailande']
armenia = armenia.loc[armenia['Produit']== 'Ananas']
armenia
# Out:
# Empty DataFrame
# Columns: [Code zone, Zone, Produit, Année, origine, Aliments pour animaux, Autres Utilisations, Disponibilité alimentaire (Kcal/personne/jour), Disponibilité alimentaire en quantité (kg/personne/an), Disponibilité de matière grasse en quantité (g/personne/jour), Disponibilité de protéines en quantité (g/personne/jour), Disponibilité intérieure, Exportations, Importations, Nourriture, Pertes, Production, Semences, Transformés, Variation de stock, Valeur, Valpop, disp_alim__kcal_an, disp_prot__kg_an, disp_alim__kg_an, ratio_e_pds__kcal_kg, prc_prot, is_cereal, ratio__autre_util__disp_inter, ratio__alim_pr_anim__nourriture_anim_hum, pop_ss_alim]
# Index: []
#
# [0 rows x 31 columns]

# %%
thai3 = thai2.loc[
    (thai2['Zone'] == 'Thaïlande')
    &(thai2['Produit'] == 'Manioc'),
].iloc[0]


thai3
# Out:
# Code zone                                                                216
# Zone                                                               Thaïlande
# Produit                                                               Manioc
# Année                                                                   2013
# origine                                                              vegetal
# Aliments pour animaux                                                   1800
# Autres Utilisations                                                     2081
# Disponibilité alimentaire (Kcal/personne/jour)                            40
# Disponibilité alimentaire en quantité (kg/personne/an)                    13
# Disponibilité de matière grasse en quantité (g/personne/jour)           0.05
# Disponibilité de protéines en quantité (g/personne/jour)                0.14
# Disponibilité intérieure                                                6264
# ...

# %%
Pourcentage pop sous alimentée en Thailande

# %%
res = 5600000/67011000*100
res
# Out:
# 8.356836937219263

# %%
La population sous alimentée représente 8.35% de la population
